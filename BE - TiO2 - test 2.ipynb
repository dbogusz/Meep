# %% [markdown]
# The code below can be divided into three parts. First, functions define_cell, define_geometry, define_point_sources, define_simulation should be run to initialise the design and simulation cell. end_simulation can be used at any point to reset the values.
#
# Then, there is a set of functions which can be run separetely (with one exception) to get results from some monitors:
#
# get_epsilon outputs the design structure in XZ plane, can be used to check whether we initated the geometry correctly
# get_ldos    outputs a local density of states of the cavity and return the wavelength at which the peak is visible (it uses max             function, so if there is no prominent peak, the result will not be true)
# get_qs      outputs first quality factor at the position of point source
# get_Er_field outputs Er field in XZ plane, centered at the point source
# get_ratio_power outputs power emitted in upward directions vs total power emitted by the source. It has to be run after defining                 monitors around the source
#
# Most of these will run their own simulations (less monitors can decrease the simulation time, you can also adjust the time_after_sources value and resolution depending on the monitor you are focusing on). To run only one simulation with all the monitors, use run_all function. Then, you can extract all the values above with extract_ldos, extract_qs, extract_Er_field, extract_ratio_power.

# %%
import meep as mp
import math
import numpy as np
import matplotlib.pyplot as plt
import argparse
import cmath

from meep.materials import Au, SiO2

Ac = mp.Medium(index=1.8)
TiO2 = mp.Medium(index=2.67)
Air = mp.Medium(index=1)

# %%
class Bullseye:
    
    def __init__(self, period, diameter, filling_factor, num, dau, ddev, dsio2, dac):
        
        self.period = period                        # period of gratings
        self.diameter = diameter                    # diameter of cavity disk
        self.filling_factor = filling_factor        # filling factor of gratings
        self.num = num                              # number of gratings
        self.dau = dau                              # thickness of gold back-reflector
        self.ddev = ddev                            # thickness of device layer (TiO2)
        self.dsio2 = dsio2                          # thickness of SiO2 spacer
        self.dac = dac                              # thickness of Ac on top of structure
        
        self._cell = None
        self._dimensions = mp.CYLINDRICAL
        self._geometry = None
        self._sources = None
        self._sim = None
        
    def define_cell(self, dpml, pad):
        
        self.dpml = dpml
        self.pad = pad
        
        self.sr = (self.num+1-self.filling_factor)*self.period+self.diameter/2+self.pad+self.dpml  # cell size in r direction
        self.sz = 2*(self.dpml+self.pad)+self.dau+self.ddev+self.dsio2 +self.dac                              # cell size in z direction
        
        self._cell = mp.Vector3(self.sr, 0, self.sz)  # define the cell size
        
    def define_geometry(self):
        
        if self._cell is not None:
            self._geometry = []
            
            self._geometry.append(mp.Block(size=mp.Vector3(self.sr,0,self.ddev),            # Add TiO2 device layer
                     center=mp.Vector3(self.sr/2,0,0),
                     material=TiO2))

            self._geometry.append(mp.Block(size=mp.Vector3(self.sr,0,self.dsio2),           # Add SiO2 spacer layer 
                     center=mp.Vector3(self.sr/2,0,-(self.ddev+self.dsio2)/2),   
                     material=SiO2))

            self._geometry.append(mp.Block(size=mp.Vector3(self.sr,0,self.dau),             # Add Au back reflector
                     center=mp.Vector3(self.sr/2,0,-(self.ddev+self.dau)/2-self.dsio2),
                     material=Au))

            self._geometry.append(mp.Block(size=mp.Vector3(self.sr,0,self.dac),             # Add Ac on top of structure
                     center=mp.Vector3(self.sr/2,0,self.ddev/2+self.dac/2),
                     material=Ac))

            for n in range (0,self.num+1,+1):                                        # Add N+1 etches (N gratings)
                self._geometry.append(mp.Block(size=mp.Vector3((1-self.filling_factor)*self.period, 0, self.ddev),
                                               center=mp.Vector3(self.diameter/2+(1-self.filling_factor)*self.period/2+n*self.period,0,0), 
                                               material=Air))
        
        else:
            raise Exception('Need a cell before defining geometry')
            
            
    def define_point_sources(self, wvl_min, wvl_max, shift):
        
        if self._geometry is not None:
        
            self.wvl_min = wvl_min
            self.wvl_max = wvl_max
            self.shift = shift         # Shift of the source position from the cavity surface in z direction 
        
            self.wvl_cen = 0.5*(self.wvl_min+self.wvl_max)
            self.fmin = 1/self.wvl_max             # min frequency
            self.fmax = 1/self.wvl_min             # max frequency
            self.fcen = 0.5*(self.fmin+self.fmax)  # center frequency
            self.df = self.fmax-self.fmin          # frequency width
            self._sources = mp.Source(mp.GaussianSource(self.fcen, fwidth=self.df), component=mp.Er, 
                                      center=mp.Vector3(0,0,self.ddev/2+self.shift))  #Add dipole-like source
        
        else:
            raise Exception('Need a geometry before defining sources')

        
    def define_simulation(self, res=100, m=+1, Courant = 0.5):
        
        if (self._cell is not None) & (self._geometry is not None) & (self._sources is not None):
            self.res = res
            self.Courant = Courant
            pml_layers = [mp.PML(self.dpml)]

            self._sim = mp.Simulation(cell_size=self._cell,
                                             geometry=self._geometry,
                                             boundary_layers=pml_layers,
                                             resolution=res,
                                             sources=[self._sources],
                                             dimensions=self._dimensions,
                                             m=m,
                                             Courant = self.Courant,
                                             default_material = Air,
                                             progress_interval = 60,
                                             force_complex_fields=True,
                                             eps_averaging= False
                                     )
        else:
            raise Exception('Environment not fully defined. Need a cell, geometry and sources')
            
    
    def end_simulation(self):
        self._sim.reset_meep()
        self._cell = None
        self._geometry = None
        self._sources = None
        self._sim = None
            
      
    def define_box_monitors(self, wvl_flux_min, wvl_flux_max, box_distance, nfreq_box): 
        # Define flux monitor encompassing the source from all directions
        
        if self._sim is not None:
            
            self.wvl_flux_min = wvl_flux_min
            self.wvl_flux_max = wvl_flux_max
        
            self.wvl_flux_cen = 0.5*(self.wvl_flux_min+self.wvl_flux_max)
            self.fmin_flux = 1/self.wvl_flux_max                  # min frequency
            self.fmax_flux = 1/self.wvl_flux_min                  # max frequency
            self.fcen_flux = 0.5*(self.fmin_flux+self.fmax_flux)  # center frequency
            self.df_flux = self.fmax_flux-self.fmin_flux          # frequency width
        
            self.box_dis = box_distance                 # Distance of monitors from the source
            self.nfreq_box = nfreq_box
        
            self.box_z1 = self._sim.add_flux(self.fcen_flux, self.df_flux, self.nfreq_box, 
                                         mp.FluxRegion(center=mp.Vector3(0,0,self.ddev/2+self.shift-self.box_dis),
                                                       size=mp.Vector3(2*self.box_dis)))
            self.box_z2 = self._sim.add_flux(self.fcen_flux, self.df_flux, self.nfreq_box, 
                                         mp.FluxRegion(center=mp.Vector3(0,0,self.ddev/2+self.shift+self.box_dis),
                                                       size=mp.Vector3(2*self.box_dis)))
            self.box_r = self._sim.add_flux(self.fcen_flux, self.df_flux, self.nfreq_box, 
                                        mp.FluxRegion(center=mp.Vector3(self.box_dis,0,self.ddev/2+self.shift),
                                                      size=mp.Vector3(z=2*self.box_dis)))
                                             
        else:
            raise Exception('Cannot run null simulation')
            

    def get_epsilon(self):  # This won't show the Au layer, since it is the only material from the meep library which accounts 
                            # for dispersion and meep doesn’t know at which frequency to output epsilon
        if self._sim is not None:
            
            self._sim.init_fields()
            self.eps_data = self._sim.get_array(center=mp.Vector3(0,0, self.ddev/2+self.shift), size=mp.Vector3(2*self.sr, 0, self.sz),
                                                  component=mp.Dielectric)
            
            plt.figure(dpi=100)
            plt.imshow(self.eps_data, interpolation='none', origin='lower', cmap="Greys")
            plt.show()

    def get_ldos(self, time_after_source=150, nfreq_ldos=200):
        if self._sim is not None:
            self.time_after_source = time_after_source
            self.nfreq_ldos=nfreq_ldos
            ldos_instance = mp.Ldos(self.fcen, self.df, self.nfreq_ldos)
            self._sim.run(mp.dft_ldos(ldos=ldos_instance), until_after_sources=self.time_after_source)
            mp.all_wait()
            if mp.am_master():
                self.ldos_results = np.transpose(
                    np.array([mp.get_ldos_freqs(ldos_instance),self._sim.ldos_data]))
                
            plt.figure(dpi=100)
            plt.plot(1 / self.ldos_results[:, 0], self.ldos_results[:, 1], 'b-')
            plt.show()
            maximum = max(self.ldos_results[:, 1])
            index = np.where(self.ldos_results[:, 1] == maximum)
            self.mode_wvl=1000/self.ldos_results[index, 0]
            print('Peak at',self.mode_wvl,'nm')
            

        else:
            raise Exception('Cannot run null simulation')

            

    def get_qs(self, time_after_source=150):
        if self._sim is not None:
            self.time_after_source = time_after_source

            harminv_instance = mp.Harminv(mp.Er, mp.Vector3(0,0,self.ddev/2+self.shift), self.fcen, self.df)

            self._sim.run(mp.after_sources(harminv_instance),
                                 until_after_sources=self.time_after_source)

            mp.all_wait()
            if mp.am_master():
                self.q_results = []
                for mode in harminv_instance.modes:
                    self.q_results.append([1000/mode.freq, mode.decay, mode.Q, abs(mode.amp)])
                    
            self.q_results = np.array(self.q_results)
            
            for i in range(len(self.q_results)):
                
                print("Wavelength in nm:", self.q_results[i,0])
                print("Decay:", self.q_results[i,1])
                print("Q factor:", self.q_results[i,2])
                print("Amplitude:", self.q_results[i,3])
                print("-")
            

    def get_Er_field(self, time_after_source=150):
        if self._sim is not None:
            self.time_after_source = time_after_source

            self._sim.run(until_after_sources=self.time_after_source)
            
            er_data_list=[]
            er_data_list.append(self._sim.get_array(center=mp.Vector3(0,0,self.ddev/2+self.shift),
                                                               size=mp.Vector3(2*self.sr, 0, self.sz),
                                                               component=mp.Er).real)
            er_data = np.array(er_data_list)
            
            for i in range(len(er_data)):
                plt.figure(i, dpi=100)
                #plt.imshow(eps_data_Y, interpolation='none', origin='lower', cmap="Greys")
                plt_data = er_data[i]
                plt.imshow(plt_data, interpolation='none', origin='lower', cmap = plt.cm.jet)

            plt.show()

    def get_ratio_power(self, time_after_sources=300):
        
        if self._sim is not None:
            
            self.time_after_source = time_after_sources

            self._sim.run(until_after_sources=self.time_after_source)
            
            flux_freqs = np.array(mp.get_flux_freqs(self.box_z2))
            flux_up = np.array(mp.get_fluxes(self.box_z2))
            flux_bot = np.array(mp.get_fluxes(self.box_z1))
            flux_side = np.array(mp.get_fluxes(self.box_r))
            flux_total= -flux_bot+flux_up-flux_side


            flux_wvl=1/flux_freqs
            plt.figure(dpi=100)
            plt.plot(flux_wvl, flux_total, 'r-', label='Total emission')

            plt.plot(flux_wvl, flux_up, 'b-',label='Upward emission')
            plt.legend(loc='upper right')
            plt.xlabel('Wavelength (µm)')
            plt.ylabel('Arbitrary intensity')

# Run one simulation for all monitors simultaneously:

    def run_all(self,time_after_source=100, nfreq_ldos=200):
        
        if self._sim is not None:
            
            self.time_after_source = time_after_source
            self.nfreq_ldos = nfreq_ldos
            
            self.harminv_instance = mp.Harminv(mp.Er, mp.Vector3(0,0,self.ddev/2+self.shift), self.fcen, self.df)
            self.ldos_instance = mp.Ldos(self.fcen, self.df, self.nfreq_ldos)
            
            self._sim.run(mp.after_sources(self.harminv_instance), mp.dft_ldos(ldos=self.ldos_instance),until_after_sources=self.time_after_source)
            
    def extract_ldos(self):
        
        if (self._sim is not None) & (self.ldos_instance is not None):
            
            if mp.am_master():
                self.ldos_results = np.transpose(
                    np.array([mp.get_ldos_freqs(self.ldos_instance),self._sim.ldos_data]))
                
            plt.figure(dpi=100)
            plt.plot(1 / self.ldos_results[:, 0], self.ldos_results[:, 1], 'b-')
            plt.show()
            maximum = max(self.ldos_results[:, 1])
            index = np.where(self.ldos_results[:, 1] == maximum)
            self.mode_wvl=1000/self.ldos_results[index, 0]
            print('Peak at',self.mode_wvl,'nm')

        else:
            raise Exception('Need to run simulation first')
            
    def extract_qs(self):
        
        if (self._sim is not None) & (self.harminv_instance is not None):
            
            if mp.am_master():
                self.q_results = []
                for mode in self.harminv_instance.modes:
                    self.q_results.append([1000/mode.freq, mode.decay, mode.Q, abs(mode.amp)])
                    
            self.q_results = np.array(self.q_results)
            
            for i in range(len(self.q_results)):
                
                print("Wavelength in nm:", self.q_results[i,0])
                print("Decay:", self.q_results[i,1])
                print("Q factor:", self.q_results[i,2])
                print("Amplitude:", self.q_results[i,3])
            
        else:
            raise Exception('Need to run simulation first')
           
    
    def extract_Er_field_z(self):
        
        if (self._sim is not None):
            
            er_data_list=[]
            er_data_list.append(self._sim.get_array(center=mp.Vector3(0,0,self.ddev/2+self.shift),
                                                               size=mp.Vector3(2*self.sr, 0, self.z),
                                                               component=mp.Er).real)
            er_data = np.array(er_data_list)
            
            for i in range(len(er_data)):
                plt.figure(i, dpi=100)
                #plt.imshow(eps_data_Y, interpolation='none', origin='lower', cmap="Greys")
                plt_data = er_data[i]
                plt.imshow(plt_data, interpolation='none', origin='lower', cmap = plt.cm.jet)

            plt.show()
            
        else:
            raise Exception('Need to run simulation first')
            
            
    def extract_ratio_power(self):
        
        if (self._sim is not None):
            
            flux_freqs = np.array(mp.get_flux_freqs(self.box_z2))
            flux_up = np.array(mp.get_fluxes(self.box_z2))
            flux_bot = np.array(mp.get_fluxes(self.box_z1))
            flux_side = np.array(mp.get_fluxes(self.box_r))
            flux_total= -flux_bot+flux_up-flux_side
            flux_upwards= np.array(mp.get_fluxes(self.box_z2))

            flux_wvl=1/flux_freqs
            plt.figure(dpi=100)
            plt.plot(flux_wvl, flux_total, 'r-', label='Total emission')

            plt.plot(flux_wvl, flux_upwards, 'b-',label='Upward emission')
            plt.legend(loc='upper right')
            plt.xlabel('Wavelength (µm)')
            plt.ylabel('Arbitrary intensity')
            
        else:
            raise Exception('Need to run simulation first')

# %%
period = 0.4            # period of the gratings (lambda)
diameter = 4*period     # diameter of the central disk 
filling_factor = 0.67   # filling factor
num = 10                # number of gratings

dpml = 0.5              # thickness of PML
pad = 3.0               # padding between structure and edge of PML
dau = 0.15              # thickness of gold backreflector
ddev = 0.22             # thickness of device layer
dsio2 = 0.07            # thickness of SiO2 spacer
dac = 0.2               # thickness of Ac layer on top


BE = Bullseye(period, diameter, filling_factor, num, dau, ddev, dsio2, dac)
BE.define_cell(dpml, pad)
BE.define_geometry()
BE.define_point_sources(wvl_min=0.7,wvl_max=0.9,shift=0.1)
BE.define_simulation(res=60)

# %%
BE.get_epsilon() # Checking the geometry
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00041008 s
# Working in Cylindrical dimensions.
# Computational cell is 8.4375 x 0 x 7.6375 with resolution 80
#      block, center = (4.216,0,0)
#           size (8.432,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.1289,7.1289,7.1289)
#      block, center = (4.216,0,-0.145)
#           size (8.432,0,0.07)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.216,0,0.21)
#           size (8.432,0,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0.866,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.266,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.666,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (2.066,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (2.466,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (2.866,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (3.266,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 4 objects not shown)...
# time for set_epsilon = 0.228343 s
# lorentzian susceptibility: frequency=9.67865, gamma=0.0806554
# -----------
# Meep: using complex fields.

# %%
BE.get_ldos(time_after_source=100,nfreq_ldos=200)  # Checking the cavity mode
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000247002 s
# Working in Cylindrical dimensions.
# Computational cell is 8.43333 x 0 x 7.63333 with resolution 60
#      block, center = (4.216,0,0)
#           size (8.432,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.1289,7.1289,7.1289)
#      block, center = (4.216,0,-0.145)
#           size (8.432,0,0.07)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.216,0,-0.255)
#           size (8.432,0,0.15)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.216,0,0.21)
#           size (8.432,0,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0.866,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.266,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.666,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (2.066,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (2.466,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (2.866,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 5 objects not shown)...
# time for set_epsilon = 0.163574 s
# lorentzian susceptibility: frequency=10.7433, gamma=1.78571
# lorentzian susceptibility: frequency=3.47141, gamma=2.01155
# lorentzian susceptibility: frequency=2.39466, gamma=0.701702
# lorentzian susceptibility: frequency=0.66944, gamma=0.278261
# lorentzian susceptibility: frequency=0.33472, gamma=0.19438
# drude susceptibility: frequency=1e-10, gamma=0.0427474
# lorentzian susceptibility: frequency=9.67865, gamma=0.0806554
# -----------
# Meep: using complex fields.
# FloatProgress(value=0.0, description='0% done ', max=131.5)
# on time step 53 (time=0.441667), 0.0756845 s/step
# on time step 107 (time=0.891667), 0.0749102 s/step
# on time step 168 (time=1.4), 0.0658091 s/step
# on time step 230 (time=1.91667), 0.0646997 s/step
# on time step 287 (time=2.39167), 0.0702593 s/step
# on time step 348 (time=2.9), 0.0661039 s/step
# on time step 413 (time=3.44167), 0.0615835 s/step
# on time step 468 (time=3.9), 0.073805 s/step
# on time step 532 (time=4.43333), 0.062778 s/step
# on time step 600 (time=5), 0.059342 s/step
# on time step 665 (time=5.54167), 0.0625395 s/step
# on time step 722 (time=6.01667), 0.0702588 s/step
# on time step 777 (time=6.475), 0.0736408 s/step
# on time step 844 (time=7.03333), 0.0603747 s/step
# Meep progress: 7.508333333333333/131.5 = 5.7% done in 60.0s, 991.2s to go
# on time step 907 (time=7.55833), 0.0638936 s/step
# on time step 973 (time=8.10833), 0.0606764 s/step
# on time step 1033 (time=8.60833), 0.0671324 s/step
# on time step 1096 (time=9.13333), 0.063594 s/step
# on time step 1159 (time=9.65833), 0.0642679 s/step
# on time step 1221 (time=10.175), 0.0648153 s/step
# on time step 1285 (time=10.7083), 0.0628353 s/step
# on time step 1349 (time=11.2417), 0.0627867 s/step
# on time step 1413 (time=11.775), 0.0629592 s/step
# on time step 1473 (time=12.275), 0.0668381 s/step
# on time step 1528 (time=12.7333), 0.0729431 s/step
# on time step 1586 (time=13.2167), 0.0691305 s/step
# on time step 1641 (time=13.675), 0.0735275 s/step
# on time step 1697 (time=14.1417), 0.0720849 s/step
# on time step 1762 (time=14.6833), 0.0619269 s/step
# Meep progress: 15.1/131.5 = 11.5% done in 120.1s, 925.7s to go
# on time step 1822 (time=15.1833), 0.0674563 s/step
# on time step 1871 (time=15.5917), 0.0821441 s/step
# on time step 1925 (time=16.0417), 0.0743879 s/step
# on time step 1973 (time=16.4417), 0.0837695 s/step
# on time step 2029 (time=16.9083), 0.0718559 s/step
# on time step 2081 (time=17.3417), 0.0770645 s/step
# on time step 2142 (time=17.85), 0.066093 s/step
# on time step 2209 (time=18.4083), 0.0603232 s/step
# on time step 2277 (time=18.975), 0.0594123 s/step
# on time step 2345 (time=19.5417), 0.0595294 s/step
# on time step 2411 (time=20.0917), 0.0611135 s/step
# on time step 2472 (time=20.6), 0.0662297 s/step
# on time step 2538 (time=21.15), 0.0612509 s/step
# on time step 2606 (time=21.7167), 0.059051 s/step
# on time step 2676 (time=22.3), 0.0578933 s/step
# Meep progress: 22.7/131.5 = 17.3% done in 180.1s, 863.3s to go
# on time step 2744 (time=22.8667), 0.0594109 s/step
# on time step 2813 (time=23.4417), 0.0589196 s/step
# on time step 2879 (time=23.9917), 0.0613455 s/step
# on time step 2946 (time=24.55), 0.0598679 s/step
# on time step 3014 (time=25.1167), 0.059532 s/step
# on time step 3083 (time=25.6917), 0.0581214 s/step
# on time step 3155 (time=26.2917), 0.0562485 s/step
# on time step 3225 (time=26.875), 0.0571472 s/step
# on time step 3296 (time=27.4667), 0.0570613 s/step
# on time step 3366 (time=28.05), 0.0574332 s/step
# on time step 3434 (time=28.6167), 0.0589088 s/step
# on time step 3506 (time=29.2167), 0.0560697 s/step
# on time step 3571 (time=29.7583), 0.0617582 s/step
# on time step 3636 (time=30.3), 0.0621392 s/step
# on time step 3704 (time=30.8667), 0.0588457 s/step
# Meep progress: 31.2/131.5 = 23.7% done in 240.2s, 772.0s to go
# on time step 3769 (time=31.4083), 0.0617207 s/step
# on time step 3840 (time=32), 0.0563395 s/step
# on time step 3910 (time=32.5833), 0.0578448 s/step
# on time step 3975 (time=33.125), 0.0617438 s/step
# on time step 4042 (time=33.6833), 0.0601811 s/step
# on time step 4110 (time=34.25), 0.0597697 s/step
# on time step 4177 (time=34.8083), 0.0599741 s/step
# on time step 4243 (time=35.3583), 0.0613627 s/step
# on time step 4309 (time=35.9083), 0.0606837 s/step
# on time step 4377 (time=36.475), 0.0590907 s/step
# on time step 4445 (time=37.0417), 0.0597445 s/step
# on time step 4511 (time=37.5917), 0.0610175 s/step
# on time step 4577 (time=38.1417), 0.0607089 s/step
# on time step 4639 (time=38.6583), 0.0647069 s/step
# on time step 4701 (time=39.175), 0.0648969 s/step
# Meep progress: 39.425/131.5 = 30.0% done in 300.2s, 701.2s to go
# on time step 4762 (time=39.6833), 0.0663137 s/step
# on time step 4828 (time=40.2333), 0.0609308 s/step
# on time step 4896 (time=40.8), 0.0589666 s/step
# on time step 4953 (time=41.275), 0.0705118 s/step
# on time step 5015 (time=41.7917), 0.0651029 s/step
# on time step 5075 (time=42.2917), 0.0674431 s/step
# on time step 5143 (time=42.8583), 0.0593741 s/step
# on time step 5201 (time=43.3417), 0.070234 s/step
# on time step 5247 (time=43.725), 0.0872306 s/step
# on time step 5305 (time=44.2083), 0.0690174 s/step
# on time step 5362 (time=44.6833), 0.072069 s/step
# on time step 5422 (time=45.1833), 0.0668203 s/step
# on time step 5486 (time=45.7167), 0.063295 s/step
# on time step 5542 (time=46.1833), 0.072004 s/step
# on time step 5603 (time=46.6917), 0.0658569 s/step
# Meep progress: 46.90833333333333/131.5 = 35.7% done in 360.3s, 649.7s to go
# on time step 5667 (time=47.225), 0.0630144 s/step
# on time step 5728 (time=47.7333), 0.0660061 s/step
# on time step 5795 (time=48.2917), 0.0600008 s/step
# on time step 5860 (time=48.8333), 0.0615389 s/step
# on time step 5927 (time=49.3917), 0.0599795 s/step
# on time step 5995 (time=49.9583), 0.0593223 s/step
# on time step 6061 (time=50.5083), 0.0611952 s/step
# on time step 6128 (time=51.0667), 0.059979 s/step
# on time step 6193 (time=51.6083), 0.0619955 s/step
# on time step 6259 (time=52.1583), 0.0609455 s/step
# on time step 6324 (time=52.7), 0.0624858 s/step
# on time step 6387 (time=53.225), 0.0635383 s/step
# on time step 6450 (time=53.75), 0.0637578 s/step
# on time step 6515 (time=54.2917), 0.0624016 s/step
# on time step 6575 (time=54.7917), 0.0675729 s/step
# Meep progress: 54.958333333333336/131.5 = 41.8% done in 420.3s, 585.4s to go
# on time step 6640 (time=55.3333), 0.0620917 s/step
# on time step 6700 (time=55.8333), 0.0676675 s/step
# on time step 6766 (time=56.3833), 0.0611667 s/step
# on time step 6835 (time=56.9583), 0.0580435 s/step
# on time step 6902 (time=57.5167), 0.0604396 s/step
# on time step 6969 (time=58.075), 0.0597445 s/step
# on time step 7037 (time=58.6417), 0.0594151 s/step
# on time step 7105 (time=59.2083), 0.0592957 s/step
# on time step 7169 (time=59.7417), 0.0631988 s/step
# on time step 7236 (time=60.3), 0.0598235 s/step
# on time step 7303 (time=60.8583), 0.0604307 s/step
# on time step 7370 (time=61.4167), 0.0601879 s/step
# on time step 7437 (time=61.975), 0.0598875 s/step
# on time step 7503 (time=62.525), 0.0608839 s/step
# on time step 7570 (time=63.0833), 0.0602756 s/step
# Meep progress: 63.19166666666666/131.5 = 48.1% done in 480.4s, 519.3s to go
# on time step 7637 (time=63.6417), 0.0604853 s/step
# on time step 7706 (time=64.2167), 0.0581534 s/step
# on time step 7770 (time=64.75), 0.0633913 s/step
# on time step 7835 (time=65.2917), 0.0624054 s/step
# on time step 7903 (time=65.8583), 0.05957 s/step
# on time step 7971 (time=66.425), 0.0596958 s/step
# on time step 8040 (time=67), 0.0586523 s/step
# on time step 8102 (time=67.5167), 0.0647613 s/step
# on time step 8173 (time=68.1083), 0.0566188 s/step
# on time step 8239 (time=68.6583), 0.0612323 s/step
# on time step 8309 (time=69.2417), 0.0576193 s/step
# on time step 8378 (time=69.8167), 0.0584135 s/step
# on time step 8444 (time=70.3667), 0.0606751 s/step
# on time step 8510 (time=70.9167), 0.0607425 s/step
# on time step 8579 (time=71.4917), 0.0589023 s/step
# Meep progress: 71.51666666666667/131.5 = 54.4% done in 540.4s, 453.2s to go
# on time step 8646 (time=72.05), 0.0605135 s/step
# on time step 8713 (time=72.6083), 0.0605367 s/step
# on time step 8779 (time=73.1583), 0.0614475 s/step
# on time step 8843 (time=73.6917), 0.0628162 s/step
# on time step 8908 (time=74.2333), 0.0620012 s/step
# on time step 8974 (time=74.7833), 0.0610633 s/step
# on time step 9037 (time=75.3083), 0.0641276 s/step
# on time step 9099 (time=75.825), 0.0648727 s/step
# on time step 9167 (time=76.3917), 0.0592678 s/step
# on time step 9235 (time=76.9583), 0.0589252 s/step
# on time step 9301 (time=77.5083), 0.0612285 s/step
# on time step 9368 (time=78.0667), 0.0601538 s/step
# on time step 9424 (time=78.5333), 0.0717609 s/step
# on time step 9471 (time=78.925), 0.0860737 s/step
# Meep progress: 79.35833333333333/131.5 = 60.3% done in 600.4s, 394.5s to go
# on time step 9528 (time=79.4), 0.0709395 s/step
# on time step 9584 (time=79.8667), 0.0716818 s/step
# on time step 9649 (time=80.4083), 0.0620194 s/step
# on time step 9706 (time=80.8833), 0.0711721 s/step
# on time step 9762 (time=81.35), 0.0714711 s/step
# on time step 9831 (time=81.925), 0.0582006 s/step
# on time step 9897 (time=82.475), 0.0611127 s/step
# on time step 9964 (time=83.0333), 0.0598854 s/step
# on time step 10032 (time=83.6), 0.0594182 s/step
# on time step 10098 (time=84.15), 0.0612207 s/step
# on time step 10168 (time=84.7333), 0.0578654 s/step
# on time step 10235 (time=85.2917), 0.060464 s/step
# on time step 10302 (time=85.85), 0.0601698 s/step
# on time step 10370 (time=86.4167), 0.0595476 s/step
# on time step 10437 (time=86.975), 0.0597601 s/step
# Meep progress: 87.43333333333334/131.5 = 66.5% done in 660.4s, 332.9s to go
# on time step 10505 (time=87.5417), 0.0594979 s/step
# on time step 10573 (time=88.1083), 0.058932 s/step
# on time step 10638 (time=88.65), 0.0618485 s/step
# on time step 10703 (time=89.1917), 0.0619066 s/step
# on time step 10761 (time=89.675), 0.0692289 s/step
# on time step 10825 (time=90.2083), 0.0632622 s/step
# on time step 10895 (time=90.7917), 0.0579367 s/step
# on time step 10959 (time=91.325), 0.0634119 s/step
# on time step 11027 (time=91.8917), 0.059626 s/step
# on time step 11092 (time=92.4333), 0.0615679 s/step
# on time step 11157 (time=92.975), 0.0620795 s/step
# on time step 11225 (time=93.5417), 0.059063 s/step
# on time step 11291 (time=94.0917), 0.0610102 s/step
# on time step 11358 (time=94.65), 0.059732 s/step
# on time step 11426 (time=95.2167), 0.0593987 s/step
# Meep progress: 95.60833333333333/131.5 = 72.7% done in 720.5s, 270.5s to go
# on time step 11494 (time=95.7833), 0.0594617 s/step
# on time step 11560 (time=96.3333), 0.0608644 s/step
# on time step 11616 (time=96.8), 0.0723466 s/step
# on time step 11670 (time=97.25), 0.0743021 s/step
# on time step 11734 (time=97.7833), 0.0631836 s/step
# on time step 11799 (time=98.325), 0.0620056 s/step
# on time step 11868 (time=98.9), 0.0580951 s/step
# on time step 11935 (time=99.4583), 0.0597635 s/step
# on time step 12000 (time=100), 0.0620342 s/step
# on time step 12067 (time=100.558), 0.059717 s/step
# on time step 12133 (time=101.108), 0.0614996 s/step
# on time step 12201 (time=101.675), 0.0594835 s/step
# on time step 12267 (time=102.225), 0.060687 s/step
# on time step 12330 (time=102.75), 0.0642028 s/step
# on time step 12396 (time=103.3), 0.0612218 s/step
# Meep progress: 103.63333333333333/131.5 = 78.8% done in 780.5s, 209.9s to go
# on time step 12463 (time=103.858), 0.0604943 s/step
# on time step 12531 (time=104.425), 0.0594189 s/step
# on time step 12598 (time=104.983), 0.0605027 s/step
# on time step 12665 (time=105.542), 0.0598652 s/step
# on time step 12736 (time=106.133), 0.057071 s/step
# on time step 12799 (time=106.658), 0.0641347 s/step
# on time step 12860 (time=107.167), 0.0658114 s/step
# on time step 12925 (time=107.708), 0.0616252 s/step
# on time step 12991 (time=108.258), 0.0612084 s/step
# on time step 13057 (time=108.808), 0.0609444 s/step
# on time step 13123 (time=109.358), 0.0614134 s/step
# on time step 13189 (time=109.908), 0.0614403 s/step
# on time step 13238 (time=110.317), 0.081673 s/step
# on time step 13291 (time=110.758), 0.0757809 s/step
# on time step 13357 (time=111.308), 0.0612728 s/step
# Meep progress: 111.58333333333333/131.5 = 84.9% done in 840.5s, 150.0s to go
# on time step 13423 (time=111.858), 0.0610805 s/step
# on time step 13490 (time=112.417), 0.0603314 s/step
# on time step 13560 (time=113), 0.0577115 s/step
# on time step 13623 (time=113.525), 0.06415 s/step
# on time step 13688 (time=114.067), 0.0618536 s/step
# on time step 13758 (time=114.65), 0.0574953 s/step
# on time step 13825 (time=115.208), 0.0602666 s/step
# on time step 13891 (time=115.758), 0.0606985 s/step
# on time step 13948 (time=116.233), 0.0702505 s/step
# on time step 14009 (time=116.742), 0.0663378 s/step
# on time step 14073 (time=117.275), 0.0629245 s/step
# on time step 14135 (time=117.792), 0.0647793 s/step
# on time step 14199 (time=118.325), 0.0626337 s/step
# on time step 14261 (time=118.842), 0.065049 s/step
# on time step 14318 (time=119.317), 0.0707988 s/step
# Meep progress: 119.49166666666666/131.5 = 90.9% done in 900.6s, 90.5s to go
# on time step 14372 (time=119.767), 0.0746946 s/step
# on time step 14424 (time=120.2), 0.0779243 s/step
# on time step 14492 (time=120.767), 0.0593413 s/step
# on time step 14561 (time=121.342), 0.0583848 s/step
# on time step 14621 (time=121.842), 0.0676869 s/step
# on time step 14680 (time=122.333), 0.0682855 s/step
# on time step 14744 (time=122.867), 0.0637871 s/step
# on time step 14803 (time=123.358), 0.0688214 s/step
# on time step 14868 (time=123.9), 0.062434 s/step
# on time step 14925 (time=124.375), 0.0705994 s/step
# on time step 14986 (time=124.883), 0.0665925 s/step
# on time step 15053 (time=125.442), 0.0604679 s/step
# on time step 15117 (time=125.975), 0.0630471 s/step
# on time step 15185 (time=126.542), 0.0590859 s/step
# on time step 15250 (time=127.083), 0.0617391 s/step
# Meep progress: 127.21666666666667/131.5 = 96.7% done in 960.6s, 32.3s to go
# on time step 15318 (time=127.65), 0.0592026 s/step
# on time step 15386 (time=128.217), 0.0594688 s/step
# on time step 15454 (time=128.783), 0.059433 s/step
# on time step 15521 (time=129.342), 0.0603426 s/step
# on time step 15580 (time=129.833), 0.0679574 s/step
# on time step 15645 (time=130.375), 0.0616842 s/step
# on time step 15714 (time=130.95), 0.0582505 s/step
# ldos0:, 1.1111111111111112, 0.12277433199874344
# ldos0:, 1.1127063890882987, 0.12173032565018356
# ldos0:, 1.1143016670654862, 0.13355522071775197
# ldos0:, 1.1158969450426737, 0.15550916711634313
# ldos0:, 1.1174922230198612, 0.16940759608742492
# ldos0:, 1.1190875009970487, 0.16310454294003746
# ldos0:, 1.1206827789742364, 0.143715860992012
# ldos0:, 1.122278056951424, 0.1287662527287818
# ldos0:, 1.1238733349286114, 0.1272002149189657
# ldos0:, 1.125468612905799, 0.13195770029797788
# ldos0:, 1.1270638908829864, 0.13072990095310186
# ldos0:, 1.128659168860174, 0.12088616586032343
# ldos0:, 1.1302544468373614, 0.11159091244328684
# ldos0:, 1.131849724814549, 0.11215853388745485
# ldos0:, 1.1334450027917364, 0.1211228109831574
# ldos0:, 1.135040280768924, 0.1283749842015345
# ldos0:, 1.1366355587461114, 0.1270266872410555
# ldos0:, 1.1382308367232992, 0.12093862043346601
# ldos0:, 1.1398261147004867, 0.11962186789608628
# ldos0:, 1.1414213926776742, 0.12689587597984187
# ldos0:, 1.1430166706548617, 0.13642014543026743
# ldos0:, 1.1446119486320492, 0.13898416526440557
# ldos0:, 1.1462072266092367, 0.13307476519845549
# ldos0:, 1.1478025045864242, 0.1266984916636483
# ldos0:, 1.1493977825636117, 0.12828675074831802
# ldos0:, 1.1509930605407992, 0.13665111295531743
# ldos0:, 1.1525883385179867, 0.14119430113302187
# ldos0:, 1.1541836164951742, 0.13275871296692604
# ldos0:, 1.155778894472362, 0.11419821956569359
# ldos0:, 1.1573741724495494, 0.099725992428475
# ldos0:, 1.158969450426737, 0.10313667307875768
# ldos0:, 1.1605647284039244, 0.12579745565869832
# ldos0:, 1.162160006381112, 0.1553174786342155
# ldos0:, 1.1637552843582994, 0.17561159222385156
# ldos0:, 1.165350562335487, 0.1789543841121466
# ldos0:, 1.1669458403126745, 0.16987762611391308
# ldos0:, 1.168541118289862, 0.15903742700457993
# ldos0:, 1.1701363962670495, 0.1538864260875952
# ldos0:, 1.171731674244237, 0.15433921506967357
# ldos0:, 1.1733269522214247, 0.1556686473106737
# ldos0:, 1.1749222301986122, 0.15423679825790915
# ldos0:, 1.1765175081757997, 0.150362382112682
# ldos0:, 1.1781127861529872, 0.1466648735467203
# ldos0:, 1.1797080641301747, 0.14474853751263103
# ldos0:, 1.1813033421073622, 0.14384323353155307
# ldos0:, 1.1828986200845497, 0.1421960391169249
# ldos0:, 1.1844938980617372, 0.13912827631297628
# ldos0:, 1.1860891760389247, 0.135520853033064
# ldos0:, 1.1876844540161122, 0.13258970309492596
# ldos0:, 1.1892797319932997, 0.13058048890648932
# ldos0:, 1.1908750099704875, 0.12874646152485678
# ldos0:, 1.192470287947675, 0.1263689471723705
# ldos0:, 1.1940655659248625, 0.12354651707667388
# ldos0:, 1.19566084390205, 0.12096786683292979
# ldos0:, 1.1972561218792375, 0.11909813071118916
# ldos0:, 1.198851399856425, 0.11774867192973987
# ldos0:, 1.2004466778336125, 0.11642140516433934
# ldos0:, 1.2020419558108, 0.11492563426727852
# ldos0:, 1.2036372337879875, 0.11355663214013775
# ldos0:, 1.205232511765175, 0.11271031092113291
# ldos0:, 1.2068277897423625, 0.11243644240723098
# ldos0:, 1.2084230677195502, 0.1124245496913752
# ldos0:, 1.2100183456967377, 0.11237606917346192
# ldos0:, 1.2116136236739252, 0.11230361135150799
# ldos0:, 1.2132089016511127, 0.11244123883430847
# ldos0:, 1.2148041796283002, 0.1129174694153931
# ldos0:, 1.2163994576054877, 0.11358392477406919
# ldos0:, 1.2179947355826752, 0.11417373607382758
# ldos0:, 1.2195900135598627, 0.1145809921273268
# ldos0:, 1.2211852915370502, 0.11494347359884904
# ldos0:, 1.2227805695142377, 0.11546216195135335
# ldos0:, 1.2243758474914253, 0.11618564753066879
# ldos0:, 1.225971125468613, 0.11699801851120833
# ldos0:, 1.2275664034458005, 0.11779595957928951
# ldos0:, 1.229161681422988, 0.11863224190496037
# ldos0:, 1.2307569594001755, 0.11966416955760323
# ldos0:, 1.232352237377363, 0.12098087272806164
# ldos0:, 1.2339475153545505, 0.12251364386602306
# ldos0:, 1.235542793331738, 0.12412330275048548
# ldos0:, 1.2371380713089255, 0.12575240183609784
# ldos0:, 1.238733349286113, 0.12746657781695492
# ldos0:, 1.2403286272633005, 0.12934766048028862
# ldos0:, 1.2419239052404882, 0.13137030361245605
# ldos0:, 1.2435191832176757, 0.13340233185387124
# ldos0:, 1.2451144611948632, 0.13532000249885953
# ldos0:, 1.2467097391720507, 0.13710232789886365
# ldos0:, 1.2483050171492382, 0.13880470772222128
# ldos0:, 1.2499002951264258, 0.1404585257615436
# ldos0:, 1.2514955731036133, 0.14202600924185751
# ldos0:, 1.2530908510808008, 0.14346780138581613
# ldos0:, 1.2546861290579883, 0.14484479307694478
# ldos0:, 1.2562814070351758, 0.14633468248516884
# ldos0:, 1.2578766850123633, 0.14814074855200687
# ldos0:, 1.2594719629895508, 0.15038954889868816
# ldos0:, 1.2610672409667383, 0.15311977520891074
# ldos0:, 1.262662518943926, 0.15635567595048577
# ldos0:, 1.2642577969211135, 0.16016445286569442
# ldos0:, 1.265853074898301, 0.16462402839864834
# ldos0:, 1.2674483528754885, 0.16973882858420164
# ldos0:, 1.269043630852676, 0.17540532677816495
# ldos0:, 1.2706389088298635, 0.1814743501120519
# ldos0:, 1.272234186807051, 0.1878509534903016
# ldos0:, 1.2738294647842385, 0.19453765428501635
# ldos0:, 1.275424742761426, 0.20159707636576538
# ldos0:, 1.2770200207386138, 0.2090966759163795
# ldos0:, 1.2786152987158013, 0.2171004085332213
# ldos0:, 1.2802105766929888, 0.22569714318831313
# ldos0:, 1.2818058546701763, 0.23500302725601582
# ldos0:, 1.2834011326473638, 0.24510809305158485
# ldos0:, 1.2849964106245513, 0.2560029459428284
# ldos0:, 1.2865916886017388, 0.26752292231867053
# ldos0:, 1.2881869665789263, 0.27928262807538295
# ldos0:, 1.2897822445561138, 0.2905554724852505
# ldos0:, 1.2913775225333013, 0.30016097710290807
# ldos0:, 1.2929728005104888, 0.30656251982392574
# ldos0:, 1.2945680784876763, 0.3083418244520414
# ldos0:, 1.2961633564648638, 0.3049270937496933
# ldos0:, 1.2977586344420515, 0.2971237271013038
# ldos0:, 1.299353912419239, 0.2869829590785503
# ldos0:, 1.3009491903964265, 0.27696872108503745
# ldos0:, 1.302544468373614, 0.26893947929895784
# ldos0:, 1.3041397463508015, 0.26364214672508623
# ldos0:, 1.305735024327989, 0.2610043573826939
# ldos0:, 1.3073303023051766, 0.26084905483562887
# ldos0:, 1.308925580282364, 0.2633516888508825
# ldos0:, 1.3105208582595516, 0.2689007423619182
# ldos0:, 1.3121161362367393, 0.27765874299457816
# ldos0:, 1.3137114142139268, 0.28940226023292714
# ldos0:, 1.3153066921911143, 0.3038606620870605
# ldos0:, 1.3169019701683018, 0.321172244286369
# ldos0:, 1.3184972481454893, 0.3419095541194845
# ldos0:, 1.3200925261226768, 0.3666117136818581
# ldos0:, 1.3216878040998643, 0.39537460895847504
# ldos0:, 1.3232830820770518, 0.42804736032734403
# ldos0:, 1.3248783600542393, 0.46484319920525075
# ldos0:, 1.3264736380314268, 0.5064378607280795
# ldos0:, 1.3280689160086143, 0.5528088488123946
# ldos0:, 1.3296641939858018, 0.6012430910483694
# ldos0:, 1.3312594719629893, 0.6451071172809075
# ldos0:, 1.332854749940177, 0.674918776449639
# ldos0:, 1.3344500279173646, 0.6817636728311741
# ldos0:, 1.336045305894552, 0.6612817776756265
# ldos0:, 1.3376405838717396, 0.6158279397082759
# ldos0:, 1.339235861848927, 0.5535328542284029
# ldos0:, 1.3408311398261146, 0.48495071993839867
# ldos0:, 1.342426417803302, 0.41926603067300167
# ldos0:, 1.3440216957804896, 0.36186788715172774
# ldos0:, 1.345616973757677, 0.3139666154960393
# ldos0:, 1.3472122517348648, 0.2738684331054037
# ldos0:, 1.3488075297120523, 0.23908642461773225
# ldos0:, 1.3504028076892398, 0.20841194035338542
# ldos0:, 1.3519980856664273, 0.18303267663181993
# ldos0:, 1.3535933636436148, 0.1659296340389573
# ldos0:, 1.3551886416208023, 0.15957764082950393
# ldos0:, 1.3567839195979898, 0.16328266904779082
# ldos0:, 1.3583791975751773, 0.17224700188172992
# ldos0:, 1.3599744755523648, 0.1795712430325377
# ldos0:, 1.3615697535295523, 0.1801424703894021
# ldos0:, 1.3631650315067398, 0.17355052182224615
# ldos0:, 1.3647603094839273, 0.16366597168681202
# ldos0:, 1.3663555874611149, 0.15520289962430242
# ldos0:, 1.3679508654383024, 0.15017432865198632
# ldos0:, 1.36954614341549, 0.1471691153380567
# ldos0:, 1.3711414213926776, 0.14370591745978578
# ldos0:, 1.372736699369865, 0.1390774783097143
# ldos0:, 1.3743319773470526, 0.1348615126411053
# ldos0:, 1.37592725532424, 0.13284043212447927
# ldos0:, 1.3775225333014276, 0.13277711529436945
# ldos0:, 1.379117811278615, 0.13252683616508767
# ldos0:, 1.3807130892558026, 0.13033452061850231
# ldos0:, 1.3823083672329903, 0.12673656023356497
# ldos0:, 1.3839036452101778, 0.12392372383209987
# ldos0:, 1.3854989231873653, 0.12326448918349865
# ldos0:, 1.3870942011645528, 0.1237821877889106
# ldos0:, 1.3886894791417403, 0.12333489124682877
# ldos0:, 1.3902847571189278, 0.12116854389433591
# ldos0:, 1.3918800350961154, 0.11887846007574686
# ldos0:, 1.3934753130733029, 0.11857936340883478
# ldos0:, 1.3950705910504904, 0.12034330557350081
# ldos0:, 1.3966658690276779, 0.12195574774959822
# ldos0:, 1.3982611470048654, 0.12144773734544936
# ldos0:, 1.3998564249820529, 0.11953735268448532
# ldos0:, 1.4014517029592404, 0.11899251834797715
# ldos0:, 1.4030469809364279, 0.12141833849187494
# ldos0:, 1.4046422589136156, 0.12516763427951408
# ldos0:, 1.406237536890803, 0.12706508901090466
# ldos0:, 1.4078328148679906, 0.12623388657692416
# ldos0:, 1.4094280928451781, 0.12553432276917678
# ldos0:, 1.4110233708223656, 0.12853190347629884
# ldos0:, 1.4126186487995531, 0.13513506781030835
# ldos0:, 1.4142139267767406, 0.14101816204807352
# ldos0:, 1.4158092047539281, 0.14191441704933244
# ldos0:, 1.4174044827311159, 0.13810777209531946
# ldos0:, 1.4189997607083034, 0.13383046042674848
# ldos0:, 1.4205950386854909, 0.13207404442554344
# ldos0:, 1.4221903166626784, 0.13102842883095303
# ldos0:, 1.4237855946398659, 0.12683030624950736
# ldos0:, 1.4253808726170534, 0.11962123347152448
# ldos0:, 1.4269761505942409, 0.11511712943772048
# ldos0:, 1.4285714285714284, 0.11858827736814463
# run 0 finished at t = 131.5 (15780 timesteps)
# Peak at [[749.37238494]] nm

# %%
BE.end_simulation()

BE.define_cell(dpml, pad)
BE.define_geometry()
BE.define_point_sources(wvl_min=0.7,wvl_max=0.9,shift=0.1)  # Narrowband source centred at the frequency found before 
                                                            # (in practice we would always like it to be around 785nm anyway)
BE.define_simulation(res=60)

BE.define_box_monitors(wvl_flux_min=0.7, wvl_flux_max=0.9, box_distance=0.1, nfreq_box=200)

BE.get_qs(time_after_source=100)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000132084 s
# Working in Cylindrical dimensions.
# Computational cell is 8.43333 x 0 x 7.63333 with resolution 60
#      block, center = (4.216,0,0)
#           size (8.432,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.1289,7.1289,7.1289)
#      block, center = (4.216,0,-0.145)
#           size (8.432,0,0.07)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.216,0,-0.255)
#           size (8.432,0,0.15)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (4.216,0,0.21)
#           size (8.432,0,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      block, center = (0.866,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.266,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (1.666,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (2.066,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (2.466,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (2.866,0,0)
#           size (0.132,0,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 5 objects not shown)...
# time for set_epsilon = 0.128709 s
# lorentzian susceptibility: frequency=10.7433, gamma=1.78571
# lorentzian susceptibility: frequency=3.47141, gamma=2.01155
# lorentzian susceptibility: frequency=2.39466, gamma=0.701702
# lorentzian susceptibility: frequency=0.66944, gamma=0.278261
# lorentzian susceptibility: frequency=0.33472, gamma=0.19438
# drude susceptibility: frequency=1e-10, gamma=0.0427474
# lorentzian susceptibility: frequency=9.67865, gamma=0.0806554
# -----------
# Meep: using complex fields.
# FloatProgress(value=0.0, description='0% done ', max=131.5)
# on time step 58 (time=0.483333), 0.0698351 s/step
# on time step 130 (time=1.08333), 0.0560573 s/step
# on time step 197 (time=1.64167), 0.0599107 s/step
# on time step 265 (time=2.20833), 0.0591075 s/step
# on time step 338 (time=2.81667), 0.0548258 s/step
# on time step 407 (time=3.39167), 0.0587488 s/step
# on time step 465 (time=3.875), 0.0699966 s/step
# on time step 521 (time=4.34167), 0.0722917 s/step
# on time step 577 (time=4.80833), 0.0715903 s/step
# on time step 637 (time=5.30833), 0.0673439 s/step
# on time step 695 (time=5.79167), 0.0698473 s/step
# on time step 738 (time=6.15), 0.0941756 s/step
# on time step 786 (time=6.55), 0.0842194 s/step
# on time step 842 (time=7.01667), 0.0714337 s/step
# Meep progress: 7.533333333333333/131.5 = 5.7% done in 60.0s, 987.6s to go
# on time step 913 (time=7.60833), 0.0567103 s/step
# on time step 983 (time=8.19167), 0.0573499 s/step
# on time step 1053 (time=8.775), 0.057512 s/step
# on time step 1123 (time=9.35833), 0.0574043 s/step
# on time step 1191 (time=9.925), 0.058948 s/step
# on time step 1254 (time=10.45), 0.063735 s/step
# on time step 1318 (time=10.9833), 0.063328 s/step
# on time step 1381 (time=11.5083), 0.0638463 s/step
# on time step 1450 (time=12.0833), 0.0589342 s/step
# on time step 1512 (time=12.6), 0.0647639 s/step
# on time step 1566 (time=13.05), 0.0751797 s/step
# on time step 1622 (time=13.5167), 0.0718536 s/step
# on time step 1669 (time=13.9083), 0.0866174 s/step
# on time step 1730 (time=14.4167), 0.0657708 s/step
# on time step 1798 (time=14.9833), 0.0596725 s/step
# Meep progress: 15.4/131.5 = 11.7% done in 120.0s, 904.9s to go
# on time step 1864 (time=15.5333), 0.0608651 s/step
# on time step 1925 (time=16.0417), 0.0657088 s/step
# on time step 1988 (time=16.5667), 0.0642791 s/step
# on time step 2046 (time=17.05), 0.0698251 s/step
# on time step 2103 (time=17.525), 0.0705816 s/step
# on time step 2169 (time=18.075), 0.0612806 s/step
# on time step 2239 (time=18.6583), 0.0577991 s/step
# on time step 2308 (time=19.2333), 0.0581899 s/step
# on time step 2378 (time=19.8167), 0.0574798 s/step
# on time step 2448 (time=20.4), 0.057427 s/step
# on time step 2518 (time=20.9833), 0.0575151 s/step
# on time step 2588 (time=21.5667), 0.0578038 s/step
# on time step 2656 (time=22.1333), 0.0590415 s/step
# on time step 2721 (time=22.675), 0.0620621 s/step
# on time step 2792 (time=23.2667), 0.0571316 s/step
# Meep progress: 23.625/131.5 = 18.0% done in 180.1s, 822.3s to go
# on time step 2859 (time=23.825), 0.0600935 s/step
# on time step 2930 (time=24.4167), 0.0563897 s/step
# on time step 3000 (time=25), 0.0576507 s/step
# on time step 3069 (time=25.575), 0.0579979 s/step
# on time step 3138 (time=26.15), 0.0586427 s/step
# on time step 3204 (time=26.7), 0.060738 s/step
# on time step 3274 (time=27.2833), 0.0578461 s/step
# on time step 3342 (time=27.85), 0.0593624 s/step
# on time step 3411 (time=28.425), 0.0581232 s/step
# on time step 3482 (time=29.0167), 0.0564389 s/step
# on time step 3552 (time=29.6), 0.0579763 s/step
# on time step 3622 (time=30.1833), 0.0573919 s/step
# on time step 3691 (time=30.7583), 0.0581628 s/step
# on time step 3757 (time=31.3083), 0.060782 s/step
# on time step 3827 (time=31.8917), 0.0578365 s/step
# Meep progress: 32.208333333333336/131.5 = 24.5% done in 240.1s, 740.2s to go
# on time step 3897 (time=32.475), 0.0574224 s/step
# on time step 3967 (time=33.0583), 0.0578702 s/step
# on time step 4034 (time=33.6167), 0.0598654 s/step
# on time step 4102 (time=34.1833), 0.0588364 s/step
# on time step 4171 (time=34.7583), 0.0587357 s/step
# on time step 4241 (time=35.3417), 0.0578712 s/step
# on time step 4310 (time=35.9167), 0.0580594 s/step
# on time step 4382 (time=36.5167), 0.0559582 s/step
# on time step 4450 (time=37.0833), 0.0589851 s/step
# on time step 4521 (time=37.675), 0.0563692 s/step
# on time step 4586 (time=38.2167), 0.0619961 s/step
# on time step 4656 (time=38.8), 0.0577041 s/step
# on time step 4727 (time=39.3917), 0.0565488 s/step
# on time step 4796 (time=39.9667), 0.0580999 s/step
# on time step 4864 (time=40.5333), 0.0594724 s/step
# Meep progress: 40.8/131.5 = 31.0% done in 300.1s, 667.2s to go
# on time step 4933 (time=41.1083), 0.0580168 s/step
# on time step 5003 (time=41.6917), 0.0579067 s/step
# on time step 5074 (time=42.2833), 0.0570374 s/step
# on time step 5144 (time=42.8667), 0.0574993 s/step
# on time step 5214 (time=43.45), 0.0577275 s/step
# on time step 5285 (time=44.0417), 0.0567742 s/step
# on time step 5354 (time=44.6167), 0.0584561 s/step
# on time step 5426 (time=45.2167), 0.0563099 s/step
# on time step 5496 (time=45.8), 0.0573839 s/step
# on time step 5565 (time=46.375), 0.0580625 s/step
# on time step 5630 (time=46.9167), 0.0623166 s/step
# on time step 5698 (time=47.4833), 0.0592121 s/step
# on time step 5768 (time=48.0667), 0.0579921 s/step
# on time step 5838 (time=48.65), 0.0574014 s/step
# on time step 5907 (time=49.225), 0.0582511 s/step
# Meep progress: 49.425/131.5 = 37.6% done in 360.1s, 598.0s to go
# on time step 5976 (time=49.8), 0.0584063 s/step
# on time step 6045 (time=50.375), 0.0580843 s/step
# on time step 6114 (time=50.95), 0.0583715 s/step
# on time step 6184 (time=51.5333), 0.0576174 s/step
# on time step 6244 (time=52.0333), 0.0667599 s/step
# on time step 6314 (time=52.6167), 0.0576097 s/step
# on time step 6381 (time=53.175), 0.0599082 s/step
# on time step 6451 (time=53.7583), 0.0579238 s/step
# on time step 6522 (time=54.35), 0.0565225 s/step
# on time step 6590 (time=54.9167), 0.0589895 s/step
# on time step 6662 (time=55.5167), 0.0561774 s/step
# on time step 6732 (time=56.1), 0.0575644 s/step
# on time step 6801 (time=56.675), 0.0591237 s/step
# on time step 6870 (time=57.25), 0.058075 s/step
# on time step 6938 (time=57.8167), 0.0591229 s/step
# Meep progress: 57.958333333333336/131.5 = 44.1% done in 420.1s, 533.1s to go
# on time step 7009 (time=58.4083), 0.0568045 s/step
# on time step 7077 (time=58.975), 0.0593176 s/step
# on time step 7143 (time=59.525), 0.0613256 s/step
# on time step 7209 (time=60.075), 0.0608297 s/step
# on time step 7275 (time=60.625), 0.0606276 s/step
# on time step 7340 (time=61.1667), 0.0622921 s/step
# on time step 7404 (time=61.7), 0.0629634 s/step
# on time step 7467 (time=62.225), 0.063567 s/step
# on time step 7523 (time=62.6917), 0.07159 s/step
# on time step 7576 (time=63.1333), 0.0757799 s/step
# on time step 7637 (time=63.6417), 0.0661989 s/step
# on time step 7689 (time=64.075), 0.0772861 s/step
# on time step 7740 (time=64.5), 0.0784899 s/step
# on time step 7799 (time=64.9917), 0.06798 s/step
# on time step 7855 (time=65.4583), 0.0714433 s/step
# Meep progress: 65.54166666666667/131.5 = 49.8% done in 480.2s, 483.2s to go
# on time step 7910 (time=65.9167), 0.0735621 s/step
# on time step 7971 (time=66.425), 0.0662611 s/step
# on time step 8025 (time=66.875), 0.0754974 s/step
# on time step 8073 (time=67.275), 0.0850309 s/step
# on time step 8133 (time=67.775), 0.0680309 s/step
# on time step 8191 (time=68.2583), 0.069037 s/step
# on time step 8257 (time=68.8083), 0.0608018 s/step
# on time step 8319 (time=69.325), 0.0650683 s/step
# on time step 8378 (time=69.8167), 0.0682102 s/step
# on time step 8442 (time=70.35), 0.0629793 s/step
# on time step 8505 (time=70.875), 0.0642962 s/step
# on time step 8568 (time=71.4), 0.0638773 s/step
# on time step 8624 (time=71.8667), 0.0724729 s/step
# on time step 8686 (time=72.3833), 0.065524 s/step
# on time step 8747 (time=72.8917), 0.0658692 s/step
# Meep progress: 72.9/131.5 = 55.4% done in 540.2s, 434.3s to go
# on time step 8809 (time=73.4083), 0.0653731 s/step
# on time step 8869 (time=73.9083), 0.0669228 s/step
# on time step 8918 (time=74.3167), 0.0822004 s/step
# on time step 8972 (time=74.7667), 0.0743956 s/step
# on time step 9018 (time=75.15), 0.0880412 s/step
# on time step 9059 (time=75.4917), 0.0982475 s/step
# on time step 9114 (time=75.95), 0.0732727 s/step
# on time step 9172 (time=76.4333), 0.0692961 s/step
# on time step 9227 (time=76.8917), 0.073216 s/step
# on time step 9286 (time=77.3833), 0.068041 s/step
# on time step 9350 (time=77.9167), 0.0625976 s/step
# on time step 9408 (time=78.4), 0.0704464 s/step
# on time step 9466 (time=78.8833), 0.0690358 s/step
# on time step 9525 (time=79.375), 0.0688113 s/step
# Meep progress: 79.85833333333333/131.5 = 60.7% done in 600.2s, 388.2s to go
# on time step 9590 (time=79.9167), 0.0618934 s/step
# on time step 9657 (time=80.475), 0.0605058 s/step
# on time step 9727 (time=81.0583), 0.0573698 s/step
# on time step 9791 (time=81.5917), 0.0629554 s/step
# on time step 9856 (time=82.1333), 0.0622489 s/step
# on time step 9915 (time=82.625), 0.0680228 s/step
# on time step 9961 (time=83.0083), 0.0886397 s/step
# on time step 10018 (time=83.4833), 0.0711609 s/step
# on time step 10084 (time=84.0333), 0.0606349 s/step
# on time step 10149 (time=84.575), 0.0617977 s/step
# on time step 10209 (time=85.075), 0.0673843 s/step
# on time step 10275 (time=85.625), 0.0608123 s/step
# on time step 10338 (time=86.15), 0.0637497 s/step
# on time step 10405 (time=86.7083), 0.0600043 s/step
# on time step 10471 (time=87.2583), 0.0608657 s/step
# Meep progress: 87.7/131.5 = 66.7% done in 660.3s, 329.8s to go
# on time step 10537 (time=87.8083), 0.0608252 s/step
# on time step 10588 (time=88.2333), 0.0785741 s/step
# on time step 10645 (time=88.7083), 0.0713717 s/step
# on time step 10705 (time=89.2083), 0.0672059 s/step
# on time step 10773 (time=89.775), 0.0590617 s/step
# on time step 10828 (time=90.2333), 0.072959 s/step
# on time step 10886 (time=90.7167), 0.0690667 s/step
# on time step 10952 (time=91.2667), 0.0606567 s/step
# on time step 11019 (time=91.825), 0.059964 s/step
# on time step 11090 (time=92.4167), 0.0568717 s/step
# on time step 11158 (time=92.9833), 0.0589719 s/step
# on time step 11230 (time=93.5833), 0.0563135 s/step
# on time step 11300 (time=94.1667), 0.0576448 s/step
# on time step 11370 (time=94.75), 0.0572079 s/step
# on time step 11441 (time=95.3417), 0.0564273 s/step
# Meep progress: 95.75833333333333/131.5 = 72.8% done in 720.3s, 268.9s to go
# on time step 11509 (time=95.9083), 0.0589492 s/step
# on time step 11578 (time=96.4833), 0.058093 s/step
# on time step 11648 (time=97.0667), 0.0574707 s/step
# on time step 11717 (time=97.6417), 0.0584945 s/step
# on time step 11788 (time=98.2333), 0.056501 s/step
# on time step 11858 (time=98.8167), 0.0579008 s/step
# on time step 11916 (time=99.3), 0.0693694 s/step
# on time step 11985 (time=99.875), 0.0586514 s/step
# on time step 12052 (time=100.433), 0.0604062 s/step
# on time step 12121 (time=101.008), 0.058567 s/step
# on time step 12190 (time=101.583), 0.058425 s/step
# on time step 12260 (time=102.167), 0.0573543 s/step
# on time step 12332 (time=102.767), 0.05633 s/step
# on time step 12397 (time=103.308), 0.0619163 s/step
# on time step 12468 (time=103.9), 0.0563915 s/step
# Meep progress: 104.26666666666667/131.5 = 79.3% done in 780.3s, 203.8s to go
# on time step 12538 (time=104.483), 0.0578531 s/step
# on time step 12608 (time=105.067), 0.0576577 s/step
# on time step 12678 (time=105.65), 0.057829 s/step
# on time step 12742 (time=106.183), 0.06332 s/step
# on time step 12813 (time=106.775), 0.0564507 s/step
# on time step 12884 (time=107.367), 0.0568711 s/step
# on time step 12952 (time=107.933), 0.0592217 s/step
# on time step 13021 (time=108.508), 0.0584595 s/step
# on time step 13091 (time=109.092), 0.057371 s/step
# on time step 13161 (time=109.675), 0.0572621 s/step
# on time step 13230 (time=110.25), 0.0581004 s/step
# on time step 13298 (time=110.817), 0.059661 s/step
# on time step 13369 (time=111.408), 0.0564711 s/step
# on time step 13431 (time=111.925), 0.0655655 s/step
# on time step 13493 (time=112.442), 0.0651301 s/step
# Meep progress: 112.69166666666666/131.5 = 85.7% done in 840.4s, 140.3s to go
# on time step 13553 (time=112.942), 0.0673553 s/step
# on time step 13605 (time=113.375), 0.078659 s/step
# on time step 13656 (time=113.8), 0.0789541 s/step
# on time step 13706 (time=114.217), 0.0815525 s/step
# on time step 13757 (time=114.642), 0.0794498 s/step
# on time step 13811 (time=115.092), 0.0752856 s/step
# on time step 13869 (time=115.575), 0.0696747 s/step
# on time step 13930 (time=116.083), 0.0661973 s/step
# on time step 13998 (time=116.65), 0.0596447 s/step
# on time step 14064 (time=117.2), 0.0614499 s/step
# on time step 14130 (time=117.75), 0.0608911 s/step
# on time step 14194 (time=118.283), 0.0630038 s/step
# on time step 14256 (time=118.8), 0.0648588 s/step
# on time step 14320 (time=119.333), 0.0631621 s/step
# on time step 14386 (time=119.883), 0.0607088 s/step
# Meep progress: 120.075/131.5 = 91.3% done in 900.4s, 85.7s to go
# on time step 14454 (time=120.45), 0.0596632 s/step
# on time step 14518 (time=120.983), 0.0628351 s/step
# on time step 14583 (time=121.525), 0.0617318 s/step
# on time step 14652 (time=122.1), 0.0586312 s/step
# on time step 14718 (time=122.65), 0.0614192 s/step
# on time step 14784 (time=123.2), 0.060822 s/step
# on time step 14846 (time=123.717), 0.0650712 s/step
# on time step 14901 (time=124.175), 0.0728575 s/step
# on time step 14969 (time=124.742), 0.0592383 s/step
# on time step 15035 (time=125.292), 0.0611735 s/step
# on time step 15102 (time=125.85), 0.0597307 s/step
# on time step 15172 (time=126.433), 0.0573374 s/step
# on time step 15240 (time=127), 0.0593988 s/step
# on time step 15309 (time=127.575), 0.0586766 s/step
# on time step 15378 (time=128.15), 0.0587885 s/step
# Meep progress: 128.275/131.5 = 97.5% done in 960.4s, 24.1s to go
# on time step 15447 (time=128.725), 0.0581019 s/step
# on time step 15518 (time=129.317), 0.056923 s/step
# on time step 15585 (time=129.875), 0.0598775 s/step
# on time step 15656 (time=130.467), 0.0564994 s/step
# on time step 15726 (time=131.05), 0.058077 s/step
# harminv0:, frequency, imag. freq., Q, |amp|, amplitude, error
# harminv0:, 1.120530317445741, -0.010273693298439152, 54.5339579884081, 0.00010961623018500313, 0.00010883836414931314+1.3035659142256638e-05i, 5.5291856321166135e-06+0.0i
# harminv0:, 1.1610791810203116, -0.0008202028188578239, 707.800043065675, 0.00017355033026721206, 0.00015003723906584852-8.722696847509832e-05i, 3.8560525654120595e-06+0.0i
# harminv0:, 1.2965259332929886, -0.010479404896364829, 61.86066604520342, 0.008472489125699473, 0.0013489394968685276+0.00836441475650771i, 7.365900774929844e-07+0.0i
# harminv0:, 1.3354751983746675, -0.009753870302373664, 68.45873263506854, 0.018515070819785567, -0.017878131406106876-0.004814588755818091i, 2.5585609743879286e-07+0.0i
# harminv0:, 1.3569741614864024, -0.003995288674949207, 169.82179160103541, 0.0007767099473370707, 0.0004949442331330049-0.0005985887974066478i, 1.1675625392792456e-06+0.0i
# harminv0:, 1.4181090009111241, -0.004478306133570867, 158.33095802456526, 1.8195968498377275e-05, -2.1379265547795124e-06+1.8069934688324327e-05i, 3.03835515228201e-05+0.0i
# run 0 finished at t = 131.5 (15780 timesteps)
# Wavelength in nm: 892.4345771201523
# Decay: -0.010273693298439152
# Q factor: 54.5339579884081
# Amplitude: 0.00010961623018500313
# -
# Wavelength in nm: 861.2677036558683
# Decay: -0.0008202028188578239
# Q factor: 707.800043065675
# Amplitude: 0.00017355033026721206
# -
# Wavelength in nm: 771.2919381875721
# Decay: -0.010479404896364829
# Q factor: 61.86066604520342
# Amplitude: 0.008472489125699473
# -
# Wavelength in nm: 748.797133198014
# Decay: -0.009753870302373664
# Q factor: 68.45873263506854
# Amplitude: 0.018515070819785567
# -
# Wavelength in nm: 736.9337076430548
# Decay: -0.003995288674949207
# Q factor: 169.82179160103541
# Amplitude: 0.0007767099473370707
# -
# Wavelength in nm: 705.164412155559
# Decay: -0.004478306133570867
# Q factor: 158.33095802456526
# Amplitude: 1.8195968498377275e-05
# -

# %%
BE.extract_ratio_power()
